# %%
# !pip install seaborn matplotlib pandas

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
t
from google.colab import files
uploaded = files.upload()

for fn in uploaded:
    df = pd.read_csv(fn)

df = df.drop(columns=['Unnamed: 0'])
df.head()
# Dataset info
df.info()

df.describe().T
plt.figure(figsize=(12,6))
df.hist(figsize=(12,8), bins=10, edgecolor='black')
plt.tight_layout()
plt.show()
avg_scores = df.mean().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=avg_scores.values, y=avg_scores.index, palette="viridis")
plt.xlabel("Average Rating")
plt.ylabel("Feedback Aspect")
plt.title("Average Scores per Feedback Aspect")
plt.show()

avg_scores
df['overall_score'] = df.mean(axis=1)

plt.figure(figsize=(6,4))
sns.histplot(df['overall_score'], kde=True, bins=15, color='teal')
plt.title("Distribution of Overall Satisfaction Scores")
plt.show()

df['overall_score'].describe()
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Feedback Aspects")
plt.show()
corr_with_recommendation = df.corr()['Course recommendation based on relevance'].sort_values(ascending=False)
corr_with_recommendation
# Out:
# ...
#      <input type="file" id="files-0082647b-0b2d-44d3-ae46-245808881431" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0082647b-0b2d-44d3-ae46-245808881431">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
